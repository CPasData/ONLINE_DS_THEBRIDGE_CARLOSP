# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
    tipo = "Electrodomesticos"
    abierta = True

    def __init__(self, nombre, direccion, num_empleados, ventas_3m):
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas_3m = ventas_3m
        
    def ventas_total(self):
        ventas = 0
        for elemento in self.ventas_3m:
            ventas = ventas + elemento
        return ventas

    def media_ventas(self):
        ventas = 0
        media_ventas = 0
        for elemento in self.ventas_3m:
            ventas = ventas + elemento
        media_ventas = ventas / self.num_empleados
        return media_ventas

    def datos_tienda(self):
        return "La tienda se llama " + self.nombre + " y su direccion es " + self.direccion

    def ventas_ult_mes(self):
        ventas = 0
        for elemento in self.ventas_3m:
            if elemento == self.ventas_3m[2]:
                ventas = ventas + elemento
            else:
                continue
        return ventas

    def proyeccion_ventas(self, inversion):
        ventas = 0
        for elemento in self.ventas_3m:
            ventas = ventas + elemento
        if inversion < 1000:
            ventas = ventas * 1.2
            return "Si invirtieras", inversion, "estarías aumentando las ventas hasta", ventas
        else:
            ventas = ventas * 1.5
            return "Si invirtieras", inversion, "estarías aumentando las ventas hasta", ventas

# %%
#2
tienda1 = Tienda("Neveras Martinez", "Calle hermanos Martinez, 178", 5, [25000, 27500, 26800])
tienda2 = Tienda("Microondas Martinez", "Avenida PIO XII", 7, [30000, 37500, 40000])
tienda3 = Tienda("Hornos Martinez", "Calle escultor Garcia", 3, [15000, 17500, 12500])

#3
print("La tienda es de",tienda1.tipo)
print(tienda1.abierta)

print("Las ventas totales de los ultimos 3 meses son", tienda1.ventas_total(),"€")

print("La media de ventas respecto al numero de empleados fueron", tienda1.media_ventas(),"€")
print(tienda1.datos_tienda())
print("Las ventas del ultimo mes fueron", tienda1.ventas_ult_mes(),"€")
print(tienda1.proyeccion_ventas(750))

#4
print("Las ventas del ultimo mes en toda la empresa fueron", (tienda1.ventas_ult_mes() + tienda2.ventas_ult_mes() + tienda3.ventas_ult_mes())) 
# Increible que la suma de los 3 ultimos meses de la primera tienda sean los mismos que la suma del ultimo mes de cada tienda

ventas_totales = 0
for elemento in (tienda1, tienda2, tienda3):
    ventas_totales = ventas_totales + elemento.ventas_3m[2]
print("Las ventas del ultimo mes en toda la empresa fueron", ventas_totales)
    
#5
for elemento in (tienda1, tienda2, tienda3):
    if elemento.direccion[:7] == "Avenida":
        print(elemento.direccion) 
    else:
        continue
# Out:
# La tienda es de Electrodomesticos
# True
# Las ventas totales de los ultimos 3 meses son 79300 €
# La media de ventas respecto al numero de empleados fueron 15860.0 €
# La tienda se llama Neveras Martinez y su direccion es Calle hermanos Martinez, 178
# Las ventas del ultimo mes fueron 26800 €
# ('Si invirtieras', 750, 'estarías aumentando las ventas hasta', 95160.0)
# Las ventas del ultimo mes en toda la empresa fueron 79300
# Las ventas del ultimo mes en toda la empresa fueron 79300
# Avenida PIO XII

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    patas = 4
    orejas = 2
    ojos = 2
    velocidad = 0

    def __init__(self, raza, pelo = "Marrón", dueño = False):
        self.raza = raza
        self.pelo = pelo
        self.dueño = dueño

    def andar(self, aumento_velocidad):
        velocidad = 0
        velocidad = velocidad + aumento_velocidad
        return f"Tu {self.raza} esta andando a {velocidad} kilometros por hora!"

    def parar(self):
        velocidad = 0
        return f"Parece que tu {self.raza} se ha parado (velocidad {velocidad})"

    def ladrar(self, raza, pelo):
        return f"GUAU! Mi raza es {self.raza} y el color de mi pelo es {pelo}"

# %%
border_collie = Perro("Border collie")

print(border_collie.raza)
print(border_collie.pelo)
print(border_collie.dueño)

print(border_collie.andar(7))
print(border_collie.parar())
# Out:
# Border collie
# Marrón
# False
# Tu Border collie esta andando a 7 kilometros por hora!
# Parece que tu Border collie se ha parado (velocidad 0)
